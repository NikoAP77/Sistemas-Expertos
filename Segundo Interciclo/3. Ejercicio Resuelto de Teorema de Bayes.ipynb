# %% [markdown]
# # Ejercicio
#
# Se hiso una encuesta a personas en las que se les preguntaba el género y si hacían ejercicios, los resultados fueron: el 40% hombres y 60% mujeres, y el 80% de los hombres y el 50% de las mujeres dijeron que practicaban algún deporte o hacían ejercicios. Conociendo estos datos, si se selecciona una persona al azar de las que respondió que hacía ejercicios ¿Cuál es la probabilidad que esta persona sea un hombre?
#
# ![WhatsApp%20Image%202020-07-22%20at%209.30.07%20AM.jpeg](attachment:WhatsApp%20Image%202020-07-22%20at%209.30.07%20AM.jpeg)
#
#
# # Ejercicio resuelto por calculadora.
#
# ![bay.PNG](attachment:bay.PNG)
#
# ![bay2.PNG](attachment:bay2.PNG)

# %%
# Teorema de Bayes en Python

def bayes(pa1,pb1,pa2,pb2):
    ps = (pa1*pb1)+(pa2*pb2)
    pab1=(pa1*pb1)/ps
    pab2=(pa2*pb2)/ps

    resultado=[]
    resultado.append([pab1,pab2])
    return resultado

print("""Ingrese el valor de P(H):""")
pH = float(input())
print("""Ingrese el valor de P(D/H):""")
pDH = float(input())
print("""Ingrese el valor de P(M):""")
pM = float(input())
print("""Ingrese el valor de P(D/M):""")
pDM = float(input())

for i in bayes(pA1,pB1,pA2,pB2):
    print("P(H/M)= ",i, end=" ")
# Out:
# Ingrese el valor de P(H):
# 0.4
# Ingrese el valor de P(D/H):
# 0.8
# Ingrese el valor de P(M):
# 0.6
# Ingrese el valor de P(D/M):
# 0.5
# P(H/M)=  [0.5161290322580645, 0.4838709677419354]
